# %% [markdown]
# # QUIZZ 1 - MODULE 1 - Introduction to Data Analysis with Python

# %%
# Q1 - radiobouton= 1 : Comma Separated Values
# What does CSV stand for ?

# %%
# Q2 - radiobouton=2 : Column
# In the data set what represents an attribute or feature?

# %%
# Q3 - radiobouton=1 : Target
# What is another name for the variable that we want to predict?

# %%
# Q4 - radiobouton=1 : df.head()
# What is the command to display the first five rows of a dataframe df?

# %%
# Q5 - radiobouton=1 : df.dtypes
# what command do you use to get the data type of each row of the dataframe df?

# %%
# Q6 - radiobouton=1 : df.describe()
# How do you get a statistical summary of a dataframe df?

# %%
# Q7 - radiobouton=1 : False
# If you use the method describe() without changing any of the arguments you 
# will get a statistical summary of all the columns of type object?

# %% [markdown]
# # QUIZZ 2 - MODULE 2 - Pre-processing Data in Python

# %%
# Q1 - radiobouton=1 : Every element in the column "symbolling" will increase 
#                      by one 
# Consider the dataframe "df" what is the result of the following operation 
# df['symbolling'] = df['symbolling'] + 1?

# %%
# Q2 - radiobouton=3 : nothing as you must set the parameter "inplace =True " 
# Consider the dataframe "df", what does the command 
# df.rename(columns={'a':'b'}) change about the dataframe "df"

# %%
# Q3 - radiobouton=2 : convert or cast the column 'price' to an integer value 
# Consider the dataframe "df" , what is the result of the following operation 
# df['price'] = df['price'].astype(int) ?

# %%
# Q4 - radiobouton=1 : 1 
# Consider the column of the dataframe df['a']. The colunm has been 
# standardized. What is the standard deviation of the values, i.e the result 
# of applying the following operation df['a'].std()

# %%
# Q5a - radiobouton=4 : Gas and diesel 
# Consider the column of the dataframe df['Fuel'], with two values 'gas' and' 
# diesel'. What will be the name of the new colunms pd.get_dummies(df['Fuel'])?

# %%
# Q5b - radiobouton=1 : 1 and 0 
# What are the values of the new columns from part 5 a)

# %% [markdown]
# # QUIZZ 3 - MODULE 3 - Exploratory Data Analysis

# %%
# Q1 - radiobouton=1 : df.describe()
# Consider the dataframe "df". Which method provides the summary statistics?

# %%
# Q2 - radiobouton=1 : The average price for each body style 
# Consider the following dataframe:
# df_test = df['body-style', 'price']
# The following operations is applied:
# df_grp = df_test.groupby(['body-style'], as_index=False).mean()
# What are resulting values of df_grp[‘price’]:

# %%
# Q3 - radiobouton=1 : False 
# Correlation implies causation :

# %%
# Q4 - radiobouton=3 : -1 
# What is the minimum possible value of Pearson's Correlation ?

# %%
# Q5 - radiobouton=2 : 1 
# What is the Pearson correlation between variables X and Y, if X=Y ?

# %% [markdown]
# # QUIZZ 4 - MODULE 4 - Model Development

# %%
# Q1 - radiobouton=3 : 100
# Let X be a dataframe with 100 rows and 5 columns, let y be the target with 100 samples,assuming all the relevant libraries and data have been imported, the following line of code has been executed:
# LR = LinearRegression()
# LR.fit(X, y)
# yhat = LR.predict(X)
# How many samples does yhat contain ?

# %%
# Q2 - radiobouton=4 : 1 
# What value of R^2 (coefficient of determination) indicates your model 
# performs best ?

# %%
# Q3 - radiobouton=2 : Although the predictor variables of Polynomial linear 
#                      regression are not linear the relationship between the 
#                      parameters or coefficients is linear. 
# What statement is true about Polynomial linear regression?

# %%
# Q4 - radiobouton=1 : False 
# The larger the mean square error, the better your model has performed

# %%
# Q5 - radiobouton=2 : Standardize the data, then perform prediction using a 
#                      linear regression model 
# Assume all the libraries are imported, y is the target and X is the features 
# or dependent variables, consider the following lines of code:
# Input = [('scale', StandardScaler()), ('model', LinearRegression())]
# pipe = Pipeline(Input)
# pipe.fit(X,y)
# ypipe = pipe.predict(X)
# What have we just done in the above code?

# %% [markdown]
# # QUIZZ 5 - MODULE 5 - Model Evaluation and Refinement

# %%
# Q1 - radiobouton=2 : 8 
# In the following plot, the vertical access shows the mean square error andthe horizontal axis represents the order of the polynomial. The red line represents the training error the blue line is the test error. What is the best order of the polynomial given the possible choices in the horizontal axis?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Q2 - radiobouton=2 : train_test_split(x_data, y_data, test_size=0.4, 
#                                       random_state=0) 
# What is the correct use of the "train_test_split" function such that 40% of 
# the data samples will be utilized for testing, the parameter "random_state" 
# is set to zero, and the input variables for the features and targets 
# are_data, y_data respectively.

# %%
# Q3 - radiobouton=2 : The average R^2 on the test data for each of the two
#                      folds 
# What is the output of cross_val_score(lre, x_data, y_data, cv=2)?

# %%
# Q4 - radiobouton=2 : RR=Ridge(alpha=10) 
# What is the code to create a ridge regression object "RR" with an alpha term 
# equal 10

# %%
# Q5 - case=2 : [{'alpha': [1,10,100]}] 
# What dictionary value would we use to perform a grid search for the following
# values of alpha: 1,10, 100. 
# No other parameter values should be tested
