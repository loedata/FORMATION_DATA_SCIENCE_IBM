# %% [markdown]
# # DATA VISUALIZATION WITH PYTHON - FINAL EXAM

# %%
# Q1 - 2, 4 et 5

# Data visualizations are used to (check all that apply)
# explore a given dataset.--------------------- OK -------------------------
# perform data analytics and build predictive models.
# train and test a machine learning algorithm.
# share unbiased representation of data.----------------- OK ----------------
# support recommendations to different stakeholders.---------- OK -----------

# %%
# Q2 - True

# Matplotlib was created by John Hunter, an American neurobiologist, and was 
# originally developed as an EEG/ECoG visualization tool.
# False
# True--------------------------- OK -------------------------

# %%
# Q3 - Backend Layer, Artist Layer, and Scripting Layer.

# What are the layers that make up the Matplotlib architecture?
# FigureCanvas Layer, Renderer Layer, and Artist Layer.
# Backend_Bases Layer, Artist Layer, Scripting Layer.
# Backend Layer, Artist Layer, and Scripting Layer.--------- OK ------------
# Backend Layer, FigureCanvas Layer, Renderer Layer, Artist Layer, and 
# Scripting Layer.
# Figure Layer, Artist Layer, and Scripting Layer.

# %%
# Q4 -True

# Using the notebook backend, you can modify a figure after it is rendered.
# False
# True------------------------------ OK ----------------------------------

# %%
# Q5 - 1 et 4

# The scripting layer is (check all that apply)
# comprised mainly of pyplot.------------------- OK ------------------------
# an area on which the figure is drawn.
# a handler of user inputs such as keyboard strokes and mouse clicks.
# lighter that the Artist layer, and is intended for scientists whose goal is 
# to perform quick exploratory analysis.---------------- OK ------------------
# comprised one one main object - Artist.

# %%
# Q6 - Titles, Tick Labels et Images

# Which of the following are instances of the Artist object? (check all that
# apply)
# Titles----------------------- OK -----------------
# Event
# FigureCanvas
# Tick Labels---------------- OK --------------------
# Images---------------------- OK -------------------

# %%
# Q7 - False

# There are three types of Artist objects.
# False--------------------------- OK ------------------------------
# True

# %%
# Q8 - False

# Each primitive artist may contain other composite artists as well as
# primitive artists.
# False------------------------------- OK --------------------
# True

# %%
# Q9 - question.plot(kind='barh')

# Given a pandas dataframe, question, which of the following will create a 
# horizontal barchart of the data in question?
# question.plot(type='bar', rot=90)
# question.plot(kind='bar', orientation='horizontal')
# question.plot(kind='barh')--------------------- OK ----------------
# question.plot(kind='bar')
# question.plot(kind='bar', type='horizontal')

# %%
# Q10 - True

# Pie charts are relevant only in the rarest of circumstances, and bar charts 
# are far superior ways to quickly get a message across.
# False
# True----------------------------- OK ------------------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Q11 - A = Median, B = Third Quartile, C = First Quartile,
#       D = Inter Quartile Range, E = Minimum, and F = Outliers

# What do the letters in the box plot above represent?

# A = Mean, B = Upper Mean Quartile, C = Lower Mean Quartile, 
# D = Inter Quartile Range, E = Minimum, and F = Outliers

# A = Mean, B = Third Quartile, C = First Quartile, D = Inter Quartile Range, 
# E = Minimum, and F = Outliers

# A = Median, B = Third Quartile, C = First Quartile,
# D = Inter Quartile Range, E = Minimum, and F = Outliers-------- OK -------

# A = Median, B = Third Quartile, C = Mean, D = Inter Quartile Range,
# E = Lower Quartile, and F = Outliers

# A = Mean, B = Third Quartile, C = First Quartile, D = Inter Quartile Range, 
# E = Minimum, and F = Maximum

# %%
# Q12 - Function = plot, and Parameter = kind, with value = "box"

# What is the correct combination of function and parameter to create a box 
# plot in Matplotlib?
# Function = plot, and Parameter = kind, with value = "boxplot"
# Function = plot, and Parameter = type, with value = "box"
# Function = plot, and Parameter = kind, with value = "box"----- OK ---------
# Function = box, and Parameter = type, with value = "plot"
# Function = boxplot, and Parameter = type, with value = "plot"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Q13 -

# Which of the lines of code below will create the following scatter plot, 
# given the pandas dataframe, df_total?

# import matplotlib.pyplot as plt
# plot(kind='scatter', x='year', y='total', data=df_total)

# plt.title('Total Immigrant population to Canada from 1980 - 2013')

# plt.label ('Year')

# plt.label('Number of Immigrants')


# import matplotlib.pyplot as plt
# df_total.plot(type='scatter', x='year', y='total')

# plt.title('Total Immigrant population to Canada from 1980 - 2013')

# plt.label ('Year')

# plt.label('Number of Immigrants')


# import matplotlib.pyplot as plt------------------------ OK ---------------
# df_total.plot(kind='scatter', x='year', y='total')

# plt.title('Total Immigrant population to Canada from 1980 - 2013')

# plt.xlabel ('Year')

# plt.ylabel('Number of Immigrants')

#------------------------- OK -----------------------------


# import matplotlib.scripting.pyplot as plt
# df_total.plot(kind='scatter', x='year', y='total')

# plt.title('Total Immigrant population to Canada from 1980 - 2013')

# plt.label ('Year')

# plt.label('Number of Immigrants')


# import matplotlib.scripting.pyplot as plt
# df_total.plot(type='scatter', y='year', x='total')

# plt.title('Total Immigrant population to Canada from 1980 - 2013')

# plt.xlabel ('Year')

# plt.ylabel('Number of Immigrants')

# %%
# Q14 - True

# A bubble plot is a variation of the scatter plot that displays three 
# dimensions of data.
# False
# True---------------------- OK -------------------------------

# %%
# Q15 - True

# Seaborn is a Python visualization library that is built on top of Matplotlib.
# False
# True------------------------- OK --------------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Q16 -

# Which of the choices below will create the following regression line plot, 
# given a pandas dataframe, data_dataframe?

# import seaborn as sns
# ax = sns.regplot(x="year", y="total", data=data_dataframe, color="green")

# data_dataframe.plot(kind="regression", color="green", marker="+")
# import seaborn as sns
# ax = sns.regplot(x="year", y="total", data=data_dataframe, color="green", 
# marker="+") ----------------------------- OK --------------------------


# data_dataframe.plot(kind="regplot", color="green", marker="+")

# import seaborn as sns
# ax = sns.regplot(x="total", y="year", data=data_dataframe, color="green")

# %%
# Q17 -

# A word cloud (choose all that apply):

# is a depiction of the frequency of different words in some textual data.
# -------------------------- OK --------------------------------

# is a depiction of the frequency of the stopwords, such as a, the, and, in
# some textual data.

# is a depiction of the meaningful words in some textual data, where the more 
# a specific word appears in the text, bigger and bolder it appears in the word
# cloud.------------------------------ OK -------------------------

# can be generated in Python using the word_cloud library that was developed by
# Andreas Mueller.--------------------------- OK -------------------

# can be easily created using Matplotlib using the scripting layer.

# %%
# Q18 - Stamen Terrain, Stamen Toner et Mapbox Bright

# The following are tile styles of folium maps (choose all that apply).
# Stamen Terrain ----------------- OK -----------------------
# River Coastal
# Stamen Toner ----------------- OK -----------------------
# Mapbox Bright ----------------- OK -----------------------
# Open Stamen

# %%
# Q19 - True

# You cluster markers superimposed onto a map in Folium using a marker cluster
# object.
# False
# True-------------------------- OK -----------------------------

# %%
# Q20 -

# If you are interested in generating a map of Spain to explore its river 
# meanders and coastal zones. Which of the following lines of code will create 
# the right map for you?
# folium.Map(location=[40.4637, 3.7492], zoom_start=6, tiles='Stamen Terrain')
# folium.Map(location=[40.4637, 3.7492], zoom_start=6, tiles='Stamen Toner')

# folium.Map(location=[40.4637, -3.7492], zoom_start=6, tiles='Stamen Toner')
# ------------------------------- OK -------------------------

# folium.Map(location=[-40.4637, -3.7492], zoom_start=6, tiles='Stamen 
# Terrain')
# folium.Map(location=[40.4637, 3.7492], zoom_start=6)
